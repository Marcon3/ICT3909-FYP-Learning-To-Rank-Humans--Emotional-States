# %% [markdown]
# # Ordinal Neural Network

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import accuracy_score
from scipy.stats import pearsonr, kendalltau
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler

# %%
project_directory = r'C:\Users\marco\OneDrive\Desktop\Final Year Project'
os.chdir(project_directory)
base_dir = os.getcwd()

# %%
class Ordinal(tf.keras.Model):
    def __init__(self, num_classes):
        super(Ordinal, self).__init__()
        self.num_classes = num_classes
        self.output_layer = tf.keras.layers.Dense(num_classes, activation='sigmoid')

    def call(self, inputs):
        outputs = self.output_layer(inputs)
        probs = tf.concat([
            outputs[..., :1],
            outputs[..., 1:] - outputs[..., :-1],
            1 - outputs[..., -1:]
        ], axis=-1)
        return outputs, probs

def create_ordinal_model(num_classes, input_dim):
    input_layer = tf.keras.Input(shape=(input_dim,))
    x = tf.keras.layers.Dense(64, activation='relu')(input_layer)
    x = tf.keras.layers.Dense(32, activation='relu')(x)
    outputs, probabilities = Ordinal(num_classes)(x)
    model = tf.keras.Model(inputs=input_layer, outputs=[outputs, probabilities])
    model.compile(optimizer='adam', loss=['sparse_categorical_crossentropy', None])
    return model

def concordance_correlation_coefficient(y_true, y_pred):
    cor = np.corrcoef(y_true, y_pred)[0][1]
    mean_true, mean_pred = np.mean(y_true), np.mean(y_pred)
    var_true, var_pred = np.var(y_true), np.var(y_pred)
    sd_true, sd_pred = np.std(y_true), np.std(y_pred)
    numerator = 2 * cor * sd_true * sd_pred
    denominator = var_true + var_pred + (mean_true - mean_pred)**2
    return numerator / denominator

def pearson_correlation_coefficient(y_true, y_pred):
    return pearsonr(y_true, y_pred)[0]

def kendalls_tau_coefficient(y_true, y_pred):
    return kendalltau(y_true, y_pred)[0]

def evaluate_individual_performance(X_test, Y_test, group_labels, ord_y_pred_score, target):
    evaluation_results = []
    for participant_id in np.unique(group_labels):
        idx = group_labels == participant_id
        participant_labels = Y_test[idx]
        participant_predictions = np.argmax(ord_y_pred_score[idx], axis=1)

        pcc_value = pearsonr(participant_labels, participant_predictions)[0]
        ccc_value = concordance_correlation_coefficient(participant_labels, participant_predictions)
        kendall_tau_value = kendalltau(participant_labels, participant_predictions)[0]

        evaluation_results.append({
            'Target': target,
            'Participant ID': participant_id,
            'PCC': pcc_value,
            'CCC': ccc_value,
            'KendallTau': kendall_tau_value
        })
    return pd.DataFrame(evaluation_results)


# Load data
input_path = os.path.join('RECOLA Ranking Algorithms', 'RECOLA_Intervals_Data', 'ArousalValenceTimeSeries_Quartiles.csv')
df = pd.read_csv(input_path)

feature_columns = [col for col in df.columns if col not in ['participant_id', 'median_arousal', 'median_valence', 'time_window', 'arousal_quartile', 'valence_quartile']]
group_kfold = GroupKFold(n_splits=10)
groups = df['participant_id']

targets = ['arousal_quartile', 'valence_quartile']
for target in targets:
    print(f"\nModeling for {target}:")
    test_accuracies = []
    all_results = [] 

    for train_index, test_index in group_kfold.split(df, groups=groups):
        X_train, X_test = df.iloc[train_index][feature_columns], df.iloc[test_index][feature_columns]
        Y_train, Y_test = df.iloc[train_index][target], df.iloc[test_index][target]
        group_labels_test = groups.iloc[test_index].values
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)

        tf.keras.backend.clear_session()
        num_features = X_train_scaled.shape[1]
        ord_model = create_ordinal_model(num_classes=11, input_dim=num_features)

        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, mode='min', restore_best_weights=True)
        ord_model.fit(X_train_scaled, Y_train, validation_data=(X_test_scaled, Y_test), epochs=4, batch_size=256, callbacks=[early_stopping], verbose=1)

        predictions = ord_model.predict(X_test_scaled)
        ord_y_pred = np.argmax(predictions[1], axis=1)
        ord_y_pred_score = predictions[0]

        individual_results_df = evaluate_individual_performance(X_test, Y_test, group_labels_test, ord_y_pred_score, target)
        all_results.append(individual_results_df)

    # Combine all results and save to CSV
    output_folder = 'RECOLA Ranking Algorithms/Evaluation/Ordinal Neural Network'
    final_results_df = pd.concat(all_results)
    output_filename = os.path.join(output_folder, f"{target}_evaluation_results.csv")
    final_results_df.to_csv(output_filename, index=False)
    print(f"Results for {target} saved to {output_filename}")
# Out:
# Modeling for arousal_quartile:
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.7277 - val_loss: 2.1185
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0335 - val_loss: 1.7551
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6351 - val_loss: 1.4991
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3619 - val_loss: 1.3318
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.7125 - val_loss: 2.0767
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8693 - val_loss: 1.6550
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4950 - val_loss: 1.4079
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2573 - val_loss: 1.2586
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4614 - val_loss: 2.6903
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9540 - val_loss: 2.1067
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6167 - val_loss: 1.7041
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3920 - val_loss: 1.4954
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0508 - val_loss: 1.6736
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5621 - val_loss: 1.3857
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2872 - val_loss: 1.2999
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1094 - val_loss: 1.2531
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.6146 - val_loss: 2.1452
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0846 - val_loss: 1.8487
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7231 - val_loss: 1.5971
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4443 - val_loss: 1.4238
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.7926 - val_loss: 2.2847
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1353 - val_loss: 1.9548
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7621 - val_loss: 1.7219
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4937 - val_loss: 1.5247
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5012 - val_loss: 2.1031
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9387 - val_loss: 1.7798
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6107 - val_loss: 1.5510
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3599 - val_loss: 1.3922
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.2752 - val_loss: 1.9648
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7623 - val_loss: 1.6647
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4670 - val_loss: 1.4997
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2890 - val_loss: 1.3940
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0075 - val_loss: 1.7851
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5268 - val_loss: 1.6502
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2608 - val_loss: 1.5761
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1101 - val_loss: 1.5412
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1583 - val_loss: 58.6618
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6631 - val_loss: 40.7458
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3648 - val_loss: 43.9701
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1839 - val_loss: 48.0903
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Results for arousal_quartile saved to RECOLA Ranking Algorithms/Evaluation/Ordinal Neural Network\arousal_quartile_evaluation_results.csv
#
# Modeling for valence_quartile:
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3150 - val_loss: 2.0568
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8730 - val_loss: 1.8084
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6272 - val_loss: 1.6082
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3971 - val_loss: 1.4103
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.3747 - val_loss: 2.0733
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8732 - val_loss: 1.7810
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5400 - val_loss: 1.5413
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3064 - val_loss: 1.3696
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5721 - val_loss: 2.2080
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0138 - val_loss: 1.8442
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6998 - val_loss: 1.6271
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4810 - val_loss: 1.4547
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.4364 - val_loss: 1.9861
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8660 - val_loss: 1.6453
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5362 - val_loss: 1.4462
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3400 - val_loss: 1.3188
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3814 - val_loss: 1.8105
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7542 - val_loss: 1.4768
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4187 - val_loss: 1.3068
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2341 - val_loss: 1.2114
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.6335 - val_loss: 2.0511
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0010 - val_loss: 1.7009
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6210 - val_loss: 1.5206
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3884 - val_loss: 1.4303
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.4587 - val_loss: 2.0659
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8722 - val_loss: 1.6859
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5200 - val_loss: 1.4536
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3366 - val_loss: 1.3209
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.7034 - val_loss: 2.4126
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0313 - val_loss: 1.9184
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6557 - val_loss: 1.6556
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3869 - val_loss: 1.4985
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3975 - val_loss: 2.1348
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8309 - val_loss: 1.8301
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4922 - val_loss: 1.6775
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2488 - val_loss: 1.6113
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 1/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.5343 - val_loss: 1.9685
# Epoch 2/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8644 - val_loss: 1.6717
# Epoch 3/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5051 - val_loss: 1.4998
# Epoch 4/4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2700 - val_loss: 1.4027
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Results for valence_quartile saved to RECOLA Ranking Algorithms/Evaluation/Ordinal Neural Network\valence_quartile_evaluation_results.csv
