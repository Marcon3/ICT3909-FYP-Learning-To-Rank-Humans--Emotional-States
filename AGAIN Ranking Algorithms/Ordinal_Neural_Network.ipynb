# %% [markdown]
# # Ordinal Neural Network

# %%
# Importing libraries
import os
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from scipy.stats import pearsonr, kendalltau
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, confusion_matrix, accuracy_score

# %%
project_directory = r'C:\Users\marco\OneDrive\Desktop\Final Year Project'
os.chdir(project_directory)
base_dir = os.getcwd()

# %%
def concordance_correlation_coefficient(y_true, y_pred):
    cor = np.corrcoef(y_true, y_pred)[0][1]
    mean_true, mean_pred = np.mean(y_true), np.mean(y_pred)
    var_true, var_pred = np.var(y_true), np.var(y_pred)
    sd_true, sd_pred = np.std(y_true), np.std(y_pred)
    numerator = 2 * cor * sd_true * sd_pred
    denominator = var_true + var_pred + (mean_true - mean_pred)**2
    ccc = numerator / denominator
    return ccc

def pearson_correlation_coefficient(y_true, y_pred):
    return pearsonr(y_true, y_pred)[0]

def kendalls_tau_coefficient(y_true, y_pred):
    return kendalltau(y_true, y_pred)[0]

def evaluate_individual_performance(X_test, Y_test, group_labels_test, ord_y_pred_score, game_name):
    evaluation_results = []
    for participant_id in np.unique(group_labels_test):
        idx = group_labels_test == participant_id
        participant_labels = Y_test[idx]
        participant_predictions = np.argmax(ord_y_pred_score[idx], axis=1)
        pcc_value = pearsonr(participant_labels, participant_predictions)[0]
        ccc_value = concordance_correlation_coefficient(participant_labels, participant_predictions)
        kendall_tau_value = kendalltau(participant_labels, participant_predictions)[0]

        evaluation_results.append({
            'Game Name': game_name,
            'Participant ID': participant_id,
            'PCC': pcc_value,
            'CCC': ccc_value,
            'KendallTau': kendall_tau_value
        })
    return pd.DataFrame(evaluation_results)

class Ordinal(tf.keras.Model):
    def __init__(self, num_classes):
        super(Ordinal, self).__init__()
        self.num_classes = num_classes
        self.output_layer = tf.keras.layers.Dense(num_classes, activation='sigmoid')

    def call(self, inputs):
        outputs = self.output_layer(inputs)
        probs = tf.concat([
            outputs[..., :1],
            outputs[..., 1:] - outputs[..., :-1],
            1 - outputs[..., -1:]
        ], axis=-1)
        return outputs, probs

def create_ordinal_model(num_classes, input_dim):
    input_layer = tf.keras.Input(shape=(input_dim,))
    x = tf.keras.layers.Dense(64, activation='relu')(input_layer)
    x = tf.keras.layers.Dense(32, activation='relu')(x)
    outputs, probabilities = Ordinal(num_classes)(x)
    model = tf.keras.Model(inputs=input_layer, outputs=[outputs, probabilities])
    model.compile(optimizer='adam', loss=['sparse_categorical_crossentropy', None])
    return model

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
warnings.filterwarnings('ignore')

input_file = os.path.join('AGAIN Ranking Algorithms', 'Data_Percentiles', 'ordinal_logistic_regression_percentiles.csv')
df = pd.read_csv(input_file)

group_kfold = GroupKFold(n_splits=10)
games = df['[control]game'].unique()

evaluation_results = []

for game in games:
    print("\n===============================================================")
    print(f'Game: {game}')
    game_df = df[df['[control]game'] == game]
    feature_cols = [col for col in df.columns if '[general]' in col]
    X = game_df[feature_cols]
    Y = game_df['arousal_label']
    groups = game_df['[control]player_id']

    train_accuracies_game = []
    test_accuracies_game = []

    for train_index, test_index in group_kfold.split(X, Y, groups):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        Y_train, Y_test = Y.iloc[train_index], Y.iloc[test_index]
        group_labels_test = groups.iloc[test_index].values

        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)

        num_features = X_train_scaled.shape[1] 
        ord_model = create_ordinal_model(num_classes=11, input_dim=num_features)

        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
        history = ord_model.fit(X_train_scaled, Y_train, validation_data=(X_test_scaled, Y_test), epochs=4, batch_size=256, callbacks=[early_stopping], verbose=1)

        ord_y_pred_score, ord_y_pred_prob = ord_model.predict(X_test_scaled)
        ord_y_pred = np.argmax(ord_y_pred_prob, axis=1)
        ord_y_pred_train = np.argmax(ord_model.predict(X_train_scaled)[1], axis=1)  

        individual_results_df = evaluate_individual_performance(X_test, Y_test, group_labels_test, ord_y_pred_score, game)
        evaluation_results.append(individual_results_df)

combined_results_df = pd.concat(evaluation_results, ignore_index=True)
combined_results_df.to_csv('AGAIN Ranking Algorithms/Evaluation/Ordinal Neural Network/ONN_evaluation_results.csv', index=False)

print("Combined individual performance evaluation results saved.")
# Out:
# ===============================================================
# Game: Heist!
# WARNING:tensorflow:From c:\Users\kostas\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:188: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.4107 - val_loss: 2.1656
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1850 - val_loss: 2.0479
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0425 - val_loss: 1.9676
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9503 - val_loss: 1.9226
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3758 - val_loss: 2.2265
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1681 - val_loss: 2.0989
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0331 - val_loss: 2.0159
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9459 - val_loss: 1.9699
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3577 - val_loss: 2.2686
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2044 - val_loss: 2.1611
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0876 - val_loss: 2.0726
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9920 - val_loss: 1.9907
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.3487 - val_loss: 2.2270
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1809 - val_loss: 2.0838
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0536 - val_loss: 1.9661
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9510 - val_loss: 1.8929
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.4302 - val_loss: 2.2951
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2815 - val_loss: 2.1969
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1780 - val_loss: 2.1189
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0939 - val_loss: 2.0521
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3829 - val_loss: 2.2163
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1981 - val_loss: 2.0765
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0676 - val_loss: 1.9874
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9687 - val_loss: 1.9107
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3809 - val_loss: 2.2395
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2293 - val_loss: 2.1051
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1099 - val_loss: 1.9844
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9976 - val_loss: 1.8936
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4823 - val_loss: 2.3319
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2788 - val_loss: 2.1967
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1188 - val_loss: 2.1020
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9966 - val_loss: 2.0349
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4592 - val_loss: 2.3028
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2729 - val_loss: 2.1580
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1361 - val_loss: 2.0314
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0281 - val_loss: 1.9276
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4889 - val_loss: 2.3318
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2656 - val_loss: 2.1546
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0808 - val_loss: 2.0201
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9509 - val_loss: 1.9438
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# ===============================================================
# Game: Shootout
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4228 - val_loss: 2.2249
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1809 - val_loss: 2.0578
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0375 - val_loss: 1.9322
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9251 - val_loss: 1.8363
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4563 - val_loss: 2.2704
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2268 - val_loss: 2.1156
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0691 - val_loss: 2.0010
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9547 - val_loss: 1.9200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.3317 - val_loss: 2.1165
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1027 - val_loss: 1.9377
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9697 - val_loss: 1.8400
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8792 - val_loss: 1.7912
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.3502 - val_loss: 2.2016
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1661 - val_loss: 2.0408
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0105 - val_loss: 1.9152
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8812 - val_loss: 1.8405
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4288 - val_loss: 2.2206
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1773 - val_loss: 2.0356
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0194 - val_loss: 1.9311
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9176 - val_loss: 1.8504
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1999 - val_loss: 2.0493
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0258 - val_loss: 1.9247
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9147 - val_loss: 1.8519
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8461 - val_loss: 1.8026
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4707 - val_loss: 2.3108
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2549 - val_loss: 2.2134
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1067 - val_loss: 2.1257
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9847 - val_loss: 2.0510
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4256 - val_loss: 2.2618
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2147 - val_loss: 2.1098
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0709 - val_loss: 1.9852
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9480 - val_loss: 1.9073
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 121/121 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.3841 - val_loss: 2.1626
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1291 - val_loss: 1.9993
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9969 - val_loss: 1.8883
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8756 - val_loss: 1.8177
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5050 - val_loss: 2.3011
# Epoch 2/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2695 - val_loss: 2.1317
# Epoch 3/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1239 - val_loss: 2.0160
# Epoch 4/4
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0025 - val_loss: 1.9435
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 123/123 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# ===============================================================
# Game: TopDown
# Epoch 1/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.5047 - val_loss: 2.2245
# Epoch 2/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2196 - val_loss: 2.0617
# Epoch 3/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0643 - val_loss: 1.9496
# Epoch 4/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9455 - val_loss: 1.8797
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3691 - val_loss: 2.1920
# Epoch 2/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1652 - val_loss: 2.0418
# Epoch 3/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0120 - val_loss: 1.9387
# Epoch 4/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9054 - val_loss: 1.8944
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.3608 - val_loss: 2.1576
# Epoch 2/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1410 - val_loss: 2.0015
# Epoch 3/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9908 - val_loss: 1.9005
# Epoch 4/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8866 - val_loss: 1.8348
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4123 - val_loss: 2.2815
# Epoch 2/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1989 - val_loss: 2.1207
# Epoch 3/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0472 - val_loss: 1.9820
# Epoch 4/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9430 - val_loss: 1.8790
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3799 - val_loss: 2.2121
# Epoch 2/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1176 - val_loss: 2.0614
# Epoch 3/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9687 - val_loss: 1.9401
# Epoch 4/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8856 - val_loss: 1.8716
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4568 - val_loss: 2.2230
# Epoch 2/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2041 - val_loss: 2.0502
# Epoch 3/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0533 - val_loss: 1.9316
# Epoch 4/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9301 - val_loss: 1.8507
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4598 - val_loss: 2.3003
# Epoch 2/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2464 - val_loss: 2.1321
# Epoch 3/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0644 - val_loss: 1.9786
# Epoch 4/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9213 - val_loss: 1.8763
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.3920 - val_loss: 2.2522
# Epoch 2/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1746 - val_loss: 2.1184
# Epoch 3/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0235 - val_loss: 2.0169
# Epoch 4/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9154 - val_loss: 1.9401
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.3772 - val_loss: 2.2088
# Epoch 2/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1575 - val_loss: 2.0271
# Epoch 3/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0084 - val_loss: 1.8916
# Epoch 4/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9021 - val_loss: 1.8088
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 1/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4007 - val_loss: 2.2921
# Epoch 2/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1912 - val_loss: 2.2211
# Epoch 3/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0400 - val_loss: 2.1678
# Epoch 4/4
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9220 - val_loss: 2.0986
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Combined individual performance evaluation results saved.
