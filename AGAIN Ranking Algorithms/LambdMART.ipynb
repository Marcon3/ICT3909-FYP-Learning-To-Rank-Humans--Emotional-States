# %% [markdown]
# # LambdaMART

# %%
# pip install lightgbm

# %%
import os
import numpy as np
import pandas as pd
import lightgbm as lgb
from scipy.stats import pearsonr, kendalltau
from sklearn.model_selection import GroupKFold

# %%
project_directory = r'C:\Users\marco\OneDrive\Desktop\Final Year Project'
os.chdir(project_directory)
base_dir = os.getcwd()

# %%
# To print the evaluation results
def print_evaluation_callback(period=1, show_stdv=True):
    def callback(env):
        if period > 0 and env.iteration % period == 0:
            result = ''
            for data_name, eval_name, value, _ in env.evaluation_result_list:
                if show_stdv:
                    result += f"{data_name}'s {eval_name}: {value:.6f} "
                else:
                    result += f"{data_name}'s {eval_name}: {value} "
            print(result)
    callback.order = 10
    return callback

input_file = os.path.join('AGAIN Ranking Algorithms','Data_Percentiles', 'ordinal_logistic_regression_percentiles.csv')

# Load data
df = pd.read_csv(input_file)

def concordance_correlation_coefficient(y_true, y_pred):
    cor = np.corrcoef(y_true, y_pred)[0][1]
    mean_true, mean_pred = np.mean(y_true), np.mean(y_pred)
    var_true, var_pred = np.var(y_true), np.var(y_pred)
    sd_true, sd_pred = np.std(y_true), np.std(y_pred)
    numerator = 2 * cor * sd_true * sd_pred
    denominator = var_true + var_pred + (mean_true - mean_pred)**2
    return numerator / denominator

def pearson_correlation_coefficient(y_true, y_pred):
    return pearsonr(y_true, y_pred)[0]

def kendalls_tau_coefficient(y_true, y_pred):
    return kendalltau(y_true, y_pred)[0]

def evaluate_individual_performance(X_test, y_test, groups_test, ranker):
    evaluation_results = []
    for group in np.unique(groups_test):
        indices = groups_test == group
        X_test_group, y_test_group = X_test[indices], y_test[indices]

        # Compute the mean of features for normalization
        X_test_group_mean = X_test_group.mean(axis=0)
        X_test_group_normalized = X_test_group - X_test_group_mean

        # Predict scores for the current participant's data
        predicted_scores = ranker.predict(X_test_group_normalized)

        # Calculate evaluation metrics
        pcc = pearson_correlation_coefficient(y_test_group, predicted_scores)
        ccc = concordance_correlation_coefficient(y_test_group, predicted_scores)
        kendall_tau = kendalls_tau_coefficient(y_test_group, predicted_scores)

        # Store the results
        evaluation_results.append({
            'Participant ID': group,
            'PCC': pcc,
            'CCC': ccc,
            'KendallTau': kendall_tau
        })

    results_df = pd.DataFrame(evaluation_results)
    return results_df

feature_cols = [col for col in df.columns if '[general]' in col]
X = df[feature_cols].values
y = df['arousal_label'].values
groups = df['[control]player_id'].values

eval_results = []
all_evaluation_results = []

# Iterate over games
games = df['[control]game'].unique()

group_kfold = GroupKFold(n_splits=10)

for game in df['[control]game'].unique():
    game_df = df[df['[control]game'] == game]
    X_game = game_df[feature_cols].values
    y_game = game_df['arousal_label'].values
    groups_game = game_df['[control]player_id'].values

    
    for train_index, test_index in group_kfold.split(X_game, y_game, groups_game):
        X_train, X_test = X_game[train_index], X_game[test_index]
        y_train, y_test = y_game[train_index], y_game[test_index]
        groups_train, groups_test = groups_game[train_index], groups_game[test_index]

        ranker = lgb.LGBMRanker(
                    objective="lambdarank",
                    boosting_type="gbdt",
                    n_estimators=10,
                    importance_type="gain",
                    metric="ndcg",
                    num_leaves=10,
                    learning_rate=0.05,
                    force_col_wise = True,
                    max_depth=-1,
                    label_gain=[i for i in range(max(y_train.max(), y_test.max()) + 1)]
                )

        train_group = np.array([np.sum(groups_train == g) for g in np.unique(groups_train)])
        test_group = np.array([np.sum(groups_test == g) for g in np.unique(groups_test)])

        ranker.fit(
            X=X_train,
            y=y_train,
            group=train_group,
            eval_set=[(X_test, y_test)],
            eval_group=[test_group],
            eval_at=[4, 8,15],
            callbacks=[print_evaluation_callback(period=1)]
        )

        # Collect evaluation results
        print("========================================================================================")
        eval_result = ranker.best_score_['valid_0']['ndcg@4'], ranker.best_score_['valid_0']['ndcg@8'], ranker.best_score_['valid_0']['ndcg@15']
        eval_results.append(eval_result)

        individual_results = evaluate_individual_performance(X_test, y_test, groups_test, ranker)
        individual_results['Game'] = game
        all_evaluation_results.append(individual_results)

output_base = os.path.join('AGAIN Ranking Algorithms','Evaluation', 'LambdaMart')


individual_results_csv = os.path.join(output_base, 'individual_evaluation_results.csv')
game_averages_csv = os.path.join(output_base, 'averages_evaluation_results.csv')

# Concatenate and save all individual evaluations
final_results_df = pd.concat(all_evaluation_results, ignore_index=True)
final_results_df.to_csv(individual_results_csv, index=False)

print("Final individual evaluation results saved.")

# Calculate average NDCG scores at 4, 8 and 15
avg_ndcg_at_4 = np.mean([result[0] for result in eval_results])
avg_ndcg_at_8 = np.mean([result[1] for result in eval_results])
avg_ndcg_at_15 = np.mean([result[2] for result in eval_results])

print(f"Average NDCG@4 Score: {avg_ndcg_at_4:.4f}")
print(f"Average NDCG@8 Score: {avg_ndcg_at_8:.4f}")
print(f"Average NDCG@15 Score: {avg_ndcg_at_15:.4f}")


game_averages = []

# Iterate over each game to calculate the mean of the evaluation metrics
game_averages = []
for game in games:
    game_subset = final_results_df[final_results_df['Game'] == game]
    avg_pcc = game_subset['PCC'].mean()
    avg_ccc = game_subset['CCC'].mean()
    avg_kendall_tau = game_subset['KendallTau'].mean()

    game_averages.append({
        'Game': game,
        'Average PCC': avg_pcc,
        'Average CCC': avg_ccc,
        'Average KendallTau': avg_kendall_tau
    })

# Convert to DataFrame
game_averages_df = pd.DataFrame(game_averages)
game_averages_df.to_csv(game_averages_csv, index=False)

print("Game averages evaluation results saved.")
# Out:
# c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\context.py:110: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\marco\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\externals\loky\backend\context.py", line 217, in _count_physical_cores
#     raise ValueError(
# [LightGBM] [Info] Total Bins 2477
# [LightGBM] [Info] Number of data points in the train set: 4042, number of used features: 11
# valid_0's ndcg@4: 0.569734 valid_0's ndcg@8: 0.608355 valid_0's ndcg@15: 0.706280
# valid_0's ndcg@4: 0.669138 valid_0's ndcg@8: 0.751442 valid_0's ndcg@15: 0.755153
# valid_0's ndcg@4: 0.705482 valid_0's ndcg@8: 0.761335 valid_0's ndcg@15: 0.781411
# valid_0's ndcg@4: 0.702994 valid_0's ndcg@8: 0.733086 valid_0's ndcg@15: 0.767057
# valid_0's ndcg@4: 0.737140 valid_0's ndcg@8: 0.751213 valid_0's ndcg@15: 0.778335
# valid_0's ndcg@4: 0.725222 valid_0's ndcg@8: 0.753276 valid_0's ndcg@15: 0.782463
# valid_0's ndcg@4: 0.707542 valid_0's ndcg@8: 0.754682 valid_0's ndcg@15: 0.781217
# valid_0's ndcg@4: 0.740331 valid_0's ndcg@8: 0.772492 valid_0's ndcg@15: 0.795134
# valid_0's ndcg@4: 0.718476 valid_0's ndcg@8: 0.767949 valid_0's ndcg@15: 0.797729
# valid_0's ndcg@4: 0.725247 valid_0's ndcg@8: 0.773714 valid_0's ndcg@15: 0.799091
# ========================================================================================
# [LightGBM] [Info] Total Bins 2475
# [LightGBM] [Info] Number of data points in the train set: 4043, number of used features: 11
# valid_0's ndcg@4: 0.607959 valid_0's ndcg@8: 0.643121 valid_0's ndcg@15: 0.720206
# valid_0's ndcg@4: 0.686319 valid_0's ndcg@8: 0.729201 valid_0's ndcg@15: 0.767766
# valid_0's ndcg@4: 0.706521 valid_0's ndcg@8: 0.723380 valid_0's ndcg@15: 0.768039
# valid_0's ndcg@4: 0.698913 valid_0's ndcg@8: 0.728561 valid_0's ndcg@15: 0.773974
# valid_0's ndcg@4: 0.691618 valid_0's ndcg@8: 0.727272 valid_0's ndcg@15: 0.772315
# valid_0's ndcg@4: 0.676752 valid_0's ndcg@8: 0.714214 valid_0's ndcg@15: 0.766467
# valid_0's ndcg@4: 0.695177 valid_0's ndcg@8: 0.724295 valid_0's ndcg@15: 0.772490
# valid_0's ndcg@4: 0.692023 valid_0's ndcg@8: 0.724091 valid_0's ndcg@15: 0.763482
# valid_0's ndcg@4: 0.693741 valid_0's ndcg@8: 0.725268 valid_0's ndcg@15: 0.763508
# valid_0's ndcg@4: 0.693534 valid_0's ndcg@8: 0.725295 valid_0's ndcg@15: 0.767343
# ========================================================================================
# [LightGBM] [Info] Total Bins 2477
# [LightGBM] [Info] Number of data points in the train set: 4044, number of used features: 11
# valid_0's ndcg@4: 0.551168 valid_0's ndcg@8: 0.637026 valid_0's ndcg@15: 0.704795
# valid_0's ndcg@4: 0.667560 valid_0's ndcg@8: 0.699356 valid_0's ndcg@15: 0.725491
# valid_0's ndcg@4: 0.724245 valid_0's ndcg@8: 0.733971 valid_0's ndcg@15: 0.739762
# valid_0's ndcg@4: 0.748258 valid_0's ndcg@8: 0.740784 valid_0's ndcg@15: 0.753484
# valid_0's ndcg@4: 0.737214 valid_0's ndcg@8: 0.728573 valid_0's ndcg@15: 0.755763
# valid_0's ndcg@4: 0.740389 valid_0's ndcg@8: 0.733113 valid_0's ndcg@15: 0.753418
# valid_0's ndcg@4: 0.740389 valid_0's ndcg@8: 0.731749 valid_0's ndcg@15: 0.751040
# valid_0's ndcg@4: 0.739678 valid_0's ndcg@8: 0.723482 valid_0's ndcg@15: 0.763485
# valid_0's ndcg@4: 0.739678 valid_0's ndcg@8: 0.724339 valid_0's ndcg@15: 0.765521
# valid_0's ndcg@4: 0.740143 valid_0's ndcg@8: 0.724673 valid_0's ndcg@15: 0.766835
# ========================================================================================
# [LightGBM] [Info] Total Bins 2478
# [LightGBM] [Info] Number of data points in the train set: 4044, number of used features: 11
# valid_0's ndcg@4: 0.672730 valid_0's ndcg@8: 0.707794 valid_0's ndcg@15: 0.752984
# valid_0's ndcg@4: 0.859797 valid_0's ndcg@8: 0.878719 valid_0's ndcg@15: 0.869541
# valid_0's ndcg@4: 0.897803 valid_0's ndcg@8: 0.886917 valid_0's ndcg@15: 0.872811
# valid_0's ndcg@4: 0.887188 valid_0's ndcg@8: 0.895968 valid_0's ndcg@15: 0.888053
# valid_0's ndcg@4: 0.892526 valid_0's ndcg@8: 0.890234 valid_0's ndcg@15: 0.888353
# valid_0's ndcg@4: 0.890972 valid_0's ndcg@8: 0.896560 valid_0's ndcg@15: 0.884124
# valid_0's ndcg@4: 0.887425 valid_0's ndcg@8: 0.896561 valid_0's ndcg@15: 0.884733
# valid_0's ndcg@4: 0.886929 valid_0's ndcg@8: 0.895924 valid_0's ndcg@15: 0.890021
# valid_0's ndcg@4: 0.879929 valid_0's ndcg@8: 0.893944 valid_0's ndcg@15: 0.883132
# valid_0's ndcg@4: 0.883789 valid_0's ndcg@8: 0.897429 valid_0's ndcg@15: 0.885484
# ========================================================================================
# [LightGBM] [Info] Total Bins 2486
# [LightGBM] [Info] Number of data points in the train set: 4044, number of used features: 11
# valid_0's ndcg@4: 0.626608 valid_0's ndcg@8: 0.692693 valid_0's ndcg@15: 0.762284
# valid_0's ndcg@4: 0.787089 valid_0's ndcg@8: 0.794471 valid_0's ndcg@15: 0.805175
# valid_0's ndcg@4: 0.847091 valid_0's ndcg@8: 0.843030 valid_0's ndcg@15: 0.822976
# valid_0's ndcg@4: 0.849783 valid_0's ndcg@8: 0.846363 valid_0's ndcg@15: 0.816973
# valid_0's ndcg@4: 0.844997 valid_0's ndcg@8: 0.840474 valid_0's ndcg@15: 0.807597
# valid_0's ndcg@4: 0.843233 valid_0's ndcg@8: 0.849818 valid_0's ndcg@15: 0.810999
# valid_0's ndcg@4: 0.839028 valid_0's ndcg@8: 0.838859 valid_0's ndcg@15: 0.821233
# valid_0's ndcg@4: 0.833948 valid_0's ndcg@8: 0.839580 valid_0's ndcg@15: 0.815538
# valid_0's ndcg@4: 0.833948 valid_0's ndcg@8: 0.846082 valid_0's ndcg@15: 0.816083
# valid_0's ndcg@4: 0.842905 valid_0's ndcg@8: 0.838230 valid_0's ndcg@15: 0.812514
# ========================================================================================
# [LightGBM] [Info] Total Bins 2485
# [LightGBM] [Info] Number of data points in the train set: 4044, number of used features: 11
# valid_0's ndcg@4: 0.716261 valid_0's ndcg@8: 0.729476 valid_0's ndcg@15: 0.752215
# valid_0's ndcg@4: 0.806014 valid_0's ndcg@8: 0.811823 valid_0's ndcg@15: 0.828592
# valid_0's ndcg@4: 0.794241 valid_0's ndcg@8: 0.811240 valid_0's ndcg@15: 0.837295
# valid_0's ndcg@4: 0.802871 valid_0's ndcg@8: 0.829565 valid_0's ndcg@15: 0.843619
# valid_0's ndcg@4: 0.808390 valid_0's ndcg@8: 0.837275 valid_0's ndcg@15: 0.854165
# valid_0's ndcg@4: 0.816199 valid_0's ndcg@8: 0.842715 valid_0's ndcg@15: 0.863962
# valid_0's ndcg@4: 0.816604 valid_0's ndcg@8: 0.838029 valid_0's ndcg@15: 0.861683
# valid_0's ndcg@4: 0.812686 valid_0's ndcg@8: 0.842388 valid_0's ndcg@15: 0.865658
# valid_0's ndcg@4: 0.825219 valid_0's ndcg@8: 0.842490 valid_0's ndcg@15: 0.864469
# valid_0's ndcg@4: 0.821709 valid_0's ndcg@8: 0.844781 valid_0's ndcg@15: 0.861210
# ========================================================================================
# [LightGBM] [Info] Total Bins 2475
# [LightGBM] [Info] Number of data points in the train set: 4044, number of used features: 11
# valid_0's ndcg@4: 0.509809 valid_0's ndcg@8: 0.568590 valid_0's ndcg@15: 0.712018
# valid_0's ndcg@4: 0.725725 valid_0's ndcg@8: 0.799522 valid_0's ndcg@15: 0.830413
# valid_0's ndcg@4: 0.817706 valid_0's ndcg@8: 0.829860 valid_0's ndcg@15: 0.851874
# valid_0's ndcg@4: 0.869108 valid_0's ndcg@8: 0.858654 valid_0's ndcg@15: 0.874878
# valid_0's ndcg@4: 0.858377 valid_0's ndcg@8: 0.856204 valid_0's ndcg@15: 0.868887
# valid_0's ndcg@4: 0.846696 valid_0's ndcg@8: 0.847858 valid_0's ndcg@15: 0.871511
# valid_0's ndcg@4: 0.837126 valid_0's ndcg@8: 0.847220 valid_0's ndcg@15: 0.877471
# valid_0's ndcg@4: 0.842380 valid_0's ndcg@8: 0.859367 valid_0's ndcg@15: 0.884710
# valid_0's ndcg@4: 0.845481 valid_0's ndcg@8: 0.853331 valid_0's ndcg@15: 0.878727
# valid_0's ndcg@4: 0.850361 valid_0's ndcg@8: 0.855224 valid_0's ndcg@15: 0.876856
# ========================================================================================
# [LightGBM] [Info] Total Bins 2483
# [LightGBM] [Info] Number of data points in the train set: 4044, number of used features: 11
# valid_0's ndcg@4: 0.662902 valid_0's ndcg@8: 0.696780 valid_0's ndcg@15: 0.712917
# valid_0's ndcg@4: 0.673409 valid_0's ndcg@8: 0.672544 valid_0's ndcg@15: 0.723441
# valid_0's ndcg@4: 0.708183 valid_0's ndcg@8: 0.691822 valid_0's ndcg@15: 0.733695
# valid_0's ndcg@4: 0.710943 valid_0's ndcg@8: 0.696545 valid_0's ndcg@15: 0.737304
# valid_0's ndcg@4: 0.708923 valid_0's ndcg@8: 0.714671 valid_0's ndcg@15: 0.745137
# valid_0's ndcg@4: 0.708286 valid_0's ndcg@8: 0.713945 valid_0's ndcg@15: 0.743102
# valid_0's ndcg@4: 0.706498 valid_0's ndcg@8: 0.710094 valid_0's ndcg@15: 0.737676
# valid_0's ndcg@4: 0.694081 valid_0's ndcg@8: 0.695526 valid_0's ndcg@15: 0.731762
# valid_0's ndcg@4: 0.691377 valid_0's ndcg@8: 0.694778 valid_0's ndcg@15: 0.730740
# valid_0's ndcg@4: 0.691377 valid_0's ndcg@8: 0.692812 valid_0's ndcg@15: 0.727210
# ========================================================================================
# [LightGBM] [Info] Total Bins 2474
# [LightGBM] [Info] Number of data points in the train set: 4044, number of used features: 11
# valid_0's ndcg@4: 0.691559 valid_0's ndcg@8: 0.722020 valid_0's ndcg@15: 0.745456
# valid_0's ndcg@4: 0.768099 valid_0's ndcg@8: 0.772668 valid_0's ndcg@15: 0.793095
# valid_0's ndcg@4: 0.718654 valid_0's ndcg@8: 0.751187 valid_0's ndcg@15: 0.773791
# valid_0's ndcg@4: 0.728160 valid_0's ndcg@8: 0.751693 valid_0's ndcg@15: 0.768216
# valid_0's ndcg@4: 0.748724 valid_0's ndcg@8: 0.768582 valid_0's ndcg@15: 0.782407
# valid_0's ndcg@4: 0.732416 valid_0's ndcg@8: 0.751557 valid_0's ndcg@15: 0.777798
# valid_0's ndcg@4: 0.735869 valid_0's ndcg@8: 0.758562 valid_0's ndcg@15: 0.779560
# valid_0's ndcg@4: 0.745703 valid_0's ndcg@8: 0.769580 valid_0's ndcg@15: 0.783437
# valid_0's ndcg@4: 0.732993 valid_0's ndcg@8: 0.783699 valid_0's ndcg@15: 0.788698
# valid_0's ndcg@4: 0.762105 valid_0's ndcg@8: 0.774281 valid_0's ndcg@15: 0.790948
# ========================================================================================
# [LightGBM] [Info] Total Bins 2480
# [LightGBM] [Info] Number of data points in the train set: 4044, number of used features: 11
# valid_0's ndcg@4: 0.553201 valid_0's ndcg@8: 0.592580 valid_0's ndcg@15: 0.684113
# valid_0's ndcg@4: 0.698956 valid_0's ndcg@8: 0.717432 valid_0's ndcg@15: 0.731441
# valid_0's ndcg@4: 0.775832 valid_0's ndcg@8: 0.774782 valid_0's ndcg@15: 0.751348
# valid_0's ndcg@4: 0.777142 valid_0's ndcg@8: 0.764846 valid_0's ndcg@15: 0.749111
# valid_0's ndcg@4: 0.787662 valid_0's ndcg@8: 0.764502 valid_0's ndcg@15: 0.752741
# valid_0's ndcg@4: 0.789190 valid_0's ndcg@8: 0.764689 valid_0's ndcg@15: 0.752469
# valid_0's ndcg@4: 0.805196 valid_0's ndcg@8: 0.788075 valid_0's ndcg@15: 0.761695
# valid_0's ndcg@4: 0.805196 valid_0's ndcg@8: 0.795153 valid_0's ndcg@15: 0.763202
# valid_0's ndcg@4: 0.798403 valid_0's ndcg@8: 0.782802 valid_0's ndcg@15: 0.759012
# valid_0's ndcg@4: 0.798403 valid_0's ndcg@8: 0.776627 valid_0's ndcg@15: 0.753637
# ========================================================================================
# [LightGBM] [Info] Total Bins 2070
# [LightGBM] [Info] Number of data points in the train set: 3904, number of used features: 10
# valid_0's ndcg@4: 0.642909 valid_0's ndcg@8: 0.673665 valid_0's ndcg@15: 0.758644
# valid_0's ndcg@4: 0.746255 valid_0's ndcg@8: 0.813093 valid_0's ndcg@15: 0.843483
# valid_0's ndcg@4: 0.833356 valid_0's ndcg@8: 0.854631 valid_0's ndcg@15: 0.862136
# valid_0's ndcg@4: 0.833398 valid_0's ndcg@8: 0.859795 valid_0's ndcg@15: 0.866700
# valid_0's ndcg@4: 0.835459 valid_0's ndcg@8: 0.858972 valid_0's ndcg@15: 0.867579
# valid_0's ndcg@4: 0.847164 valid_0's ndcg@8: 0.865757 valid_0's ndcg@15: 0.871718
# valid_0's ndcg@4: 0.821756 valid_0's ndcg@8: 0.852339 valid_0's ndcg@15: 0.863692
# valid_0's ndcg@4: 0.813024 valid_0's ndcg@8: 0.850851 valid_0's ndcg@15: 0.861724
# valid_0's ndcg@4: 0.810119 valid_0's ndcg@8: 0.848911 valid_0's ndcg@15: 0.860384
# valid_0's ndcg@4: 0.802017 valid_0's ndcg@8: 0.845842 valid_0's ndcg@15: 0.858361
# ========================================================================================
# [LightGBM] [Info] Total Bins 2071
# [LightGBM] [Info] Number of data points in the train set: 3906, number of used features: 10
# valid_0's ndcg@4: 0.394343 valid_0's ndcg@8: 0.437974 valid_0's ndcg@15: 0.597654
# valid_0's ndcg@4: 0.681270 valid_0's ndcg@8: 0.758902 valid_0's ndcg@15: 0.782156
# valid_0's ndcg@4: 0.808560 valid_0's ndcg@8: 0.827177 valid_0's ndcg@15: 0.828966
# valid_0's ndcg@4: 0.802975 valid_0's ndcg@8: 0.824212 valid_0's ndcg@15: 0.831260
# valid_0's ndcg@4: 0.810302 valid_0's ndcg@8: 0.824725 valid_0's ndcg@15: 0.832166
# valid_0's ndcg@4: 0.805764 valid_0's ndcg@8: 0.823488 valid_0's ndcg@15: 0.835519
# valid_0's ndcg@4: 0.800618 valid_0's ndcg@8: 0.823161 valid_0's ndcg@15: 0.834005
# valid_0's ndcg@4: 0.806621 valid_0's ndcg@8: 0.828429 valid_0's ndcg@15: 0.834344
# valid_0's ndcg@4: 0.818585 valid_0's ndcg@8: 0.830300 valid_0's ndcg@15: 0.836632
# valid_0's ndcg@4: 0.819756 valid_0's ndcg@8: 0.830748 valid_0's ndcg@15: 0.836986
# ========================================================================================
# [LightGBM] [Info] Total Bins 2071
# [LightGBM] [Info] Number of data points in the train set: 3867, number of used features: 10
# valid_0's ndcg@4: 0.487951 valid_0's ndcg@8: 0.560860 valid_0's ndcg@15: 0.704717
# valid_0's ndcg@4: 0.733008 valid_0's ndcg@8: 0.816302 valid_0's ndcg@15: 0.851931
# valid_0's ndcg@4: 0.832413 valid_0's ndcg@8: 0.865526 valid_0's ndcg@15: 0.884679
# valid_0's ndcg@4: 0.877696 valid_0's ndcg@8: 0.879100 valid_0's ndcg@15: 0.893434
# valid_0's ndcg@4: 0.876614 valid_0's ndcg@8: 0.878939 valid_0's ndcg@15: 0.897636
# valid_0's ndcg@4: 0.869569 valid_0's ndcg@8: 0.878235 valid_0's ndcg@15: 0.898243
# valid_0's ndcg@4: 0.869569 valid_0's ndcg@8: 0.882708 valid_0's ndcg@15: 0.898544
# valid_0's ndcg@4: 0.833821 valid_0's ndcg@8: 0.874399 valid_0's ndcg@15: 0.893335
# valid_0's ndcg@4: 0.848817 valid_0's ndcg@8: 0.876503 valid_0's ndcg@15: 0.896624
# valid_0's ndcg@4: 0.848817 valid_0's ndcg@8: 0.876279 valid_0's ndcg@15: 0.896443
# ========================================================================================
# [LightGBM] [Info] Total Bins 2072
# [LightGBM] [Info] Number of data points in the train set: 3867, number of used features: 10
# valid_0's ndcg@4: 0.618061 valid_0's ndcg@8: 0.679177 valid_0's ndcg@15: 0.779581
# valid_0's ndcg@4: 0.746433 valid_0's ndcg@8: 0.806918 valid_0's ndcg@15: 0.844225
# valid_0's ndcg@4: 0.761073 valid_0's ndcg@8: 0.808876 valid_0's ndcg@15: 0.846770
# valid_0's ndcg@4: 0.778120 valid_0's ndcg@8: 0.825489 valid_0's ndcg@15: 0.854453
# valid_0's ndcg@4: 0.781985 valid_0's ndcg@8: 0.822635 valid_0's ndcg@15: 0.856364
# valid_0's ndcg@4: 0.781718 valid_0's ndcg@8: 0.820964 valid_0's ndcg@15: 0.855100
# valid_0's ndcg@4: 0.764275 valid_0's ndcg@8: 0.818619 valid_0's ndcg@15: 0.853339
# valid_0's ndcg@4: 0.779851 valid_0's ndcg@8: 0.824064 valid_0's ndcg@15: 0.860474
# valid_0's ndcg@4: 0.779932 valid_0's ndcg@8: 0.824575 valid_0's ndcg@15: 0.860332
# valid_0's ndcg@4: 0.781775 valid_0's ndcg@8: 0.827659 valid_0's ndcg@15: 0.861524
# ========================================================================================
# [LightGBM] [Info] Total Bins 2072
# [LightGBM] [Info] Number of data points in the train set: 3867, number of used features: 10
# valid_0's ndcg@4: 0.600314 valid_0's ndcg@8: 0.663177 valid_0's ndcg@15: 0.770951
# valid_0's ndcg@4: 0.818463 valid_0's ndcg@8: 0.871277 valid_0's ndcg@15: 0.893789
# valid_0's ndcg@4: 0.874347 valid_0's ndcg@8: 0.895131 valid_0's ndcg@15: 0.912717
# valid_0's ndcg@4: 0.874165 valid_0's ndcg@8: 0.893952 valid_0's ndcg@15: 0.913682
# valid_0's ndcg@4: 0.880248 valid_0's ndcg@8: 0.899466 valid_0's ndcg@15: 0.915180
# valid_0's ndcg@4: 0.877688 valid_0's ndcg@8: 0.902779 valid_0's ndcg@15: 0.915994
# valid_0's ndcg@4: 0.873815 valid_0's ndcg@8: 0.906224 valid_0's ndcg@15: 0.913554
# valid_0's ndcg@4: 0.876502 valid_0's ndcg@8: 0.904655 valid_0's ndcg@15: 0.912633
# valid_0's ndcg@4: 0.871409 valid_0's ndcg@8: 0.903278 valid_0's ndcg@15: 0.911502
# valid_0's ndcg@4: 0.872107 valid_0's ndcg@8: 0.903579 valid_0's ndcg@15: 0.911814
# ========================================================================================
# [LightGBM] [Info] Total Bins 2072
# [LightGBM] [Info] Number of data points in the train set: 3867, number of used features: 10
# valid_0's ndcg@4: 0.627582 valid_0's ndcg@8: 0.673376 valid_0's ndcg@15: 0.746151
# valid_0's ndcg@4: 0.772395 valid_0's ndcg@8: 0.784111 valid_0's ndcg@15: 0.832072
# valid_0's ndcg@4: 0.789315 valid_0's ndcg@8: 0.789494 valid_0's ndcg@15: 0.844316
# valid_0's ndcg@4: 0.778226 valid_0's ndcg@8: 0.779634 valid_0's ndcg@15: 0.838306
# valid_0's ndcg@4: 0.746145 valid_0's ndcg@8: 0.778666 valid_0's ndcg@15: 0.836074
# valid_0's ndcg@4: 0.740906 valid_0's ndcg@8: 0.773296 valid_0's ndcg@15: 0.832420
# valid_0's ndcg@4: 0.735872 valid_0's ndcg@8: 0.771026 valid_0's ndcg@15: 0.831155
# valid_0's ndcg@4: 0.747038 valid_0's ndcg@8: 0.775529 valid_0's ndcg@15: 0.834521
# valid_0's ndcg@4: 0.740360 valid_0's ndcg@8: 0.775021 valid_0's ndcg@15: 0.834148
# valid_0's ndcg@4: 0.734758 valid_0's ndcg@8: 0.771436 valid_0's ndcg@15: 0.831862
# ========================================================================================
# [LightGBM] [Info] Total Bins 2072
# [LightGBM] [Info] Number of data points in the train set: 3867, number of used features: 10
# valid_0's ndcg@4: 0.540509 valid_0's ndcg@8: 0.578710 valid_0's ndcg@15: 0.666642
# valid_0's ndcg@4: 0.717150 valid_0's ndcg@8: 0.752992 valid_0's ndcg@15: 0.775645
# valid_0's ndcg@4: 0.748994 valid_0's ndcg@8: 0.775987 valid_0's ndcg@15: 0.793982
# valid_0's ndcg@4: 0.749171 valid_0's ndcg@8: 0.774991 valid_0's ndcg@15: 0.792706
# valid_0's ndcg@4: 0.756081 valid_0's ndcg@8: 0.780388 valid_0's ndcg@15: 0.788009
# valid_0's ndcg@4: 0.757148 valid_0's ndcg@8: 0.783770 valid_0's ndcg@15: 0.788317
# valid_0's ndcg@4: 0.751820 valid_0's ndcg@8: 0.776109 valid_0's ndcg@15: 0.784961
# valid_0's ndcg@4: 0.754847 valid_0's ndcg@8: 0.781008 valid_0's ndcg@15: 0.786367
# valid_0's ndcg@4: 0.754847 valid_0's ndcg@8: 0.777643 valid_0's ndcg@15: 0.785533
# valid_0's ndcg@4: 0.753295 valid_0's ndcg@8: 0.778741 valid_0's ndcg@15: 0.786439
# ========================================================================================
# [LightGBM] [Info] Total Bins 2072
# [LightGBM] [Info] Number of data points in the train set: 3867, number of used features: 10
# valid_0's ndcg@4: 0.679971 valid_0's ndcg@8: 0.713593 valid_0's ndcg@15: 0.747962
# valid_0's ndcg@4: 0.725349 valid_0's ndcg@8: 0.757072 valid_0's ndcg@15: 0.770377
# valid_0's ndcg@4: 0.721144 valid_0's ndcg@8: 0.758200 valid_0's ndcg@15: 0.774768
# valid_0's ndcg@4: 0.735425 valid_0's ndcg@8: 0.763425 valid_0's ndcg@15: 0.780399
# valid_0's ndcg@4: 0.730348 valid_0's ndcg@8: 0.761429 valid_0's ndcg@15: 0.780633
# valid_0's ndcg@4: 0.729610 valid_0's ndcg@8: 0.758576 valid_0's ndcg@15: 0.779763
# valid_0's ndcg@4: 0.743123 valid_0's ndcg@8: 0.762826 valid_0's ndcg@15: 0.782212
# valid_0's ndcg@4: 0.742657 valid_0's ndcg@8: 0.765314 valid_0's ndcg@15: 0.780024
# valid_0's ndcg@4: 0.735015 valid_0's ndcg@8: 0.758262 valid_0's ndcg@15: 0.778806
# valid_0's ndcg@4: 0.731002 valid_0's ndcg@8: 0.763856 valid_0's ndcg@15: 0.779014
# ========================================================================================
# [LightGBM] [Info] Total Bins 2071
# [LightGBM] [Info] Number of data points in the train set: 3907, number of used features: 10
# valid_0's ndcg@4: 0.619297 valid_0's ndcg@8: 0.688986 valid_0's ndcg@15: 0.768807
# valid_0's ndcg@4: 0.730338 valid_0's ndcg@8: 0.784062 valid_0's ndcg@15: 0.840549
# valid_0's ndcg@4: 0.812683 valid_0's ndcg@8: 0.847012 valid_0's ndcg@15: 0.867490
# valid_0's ndcg@4: 0.832299 valid_0's ndcg@8: 0.850336 valid_0's ndcg@15: 0.871882
# valid_0's ndcg@4: 0.838518 valid_0's ndcg@8: 0.855305 valid_0's ndcg@15: 0.873596
# valid_0's ndcg@4: 0.842213 valid_0's ndcg@8: 0.858556 valid_0's ndcg@15: 0.875824
# valid_0's ndcg@4: 0.841702 valid_0's ndcg@8: 0.858038 valid_0's ndcg@15: 0.876333
# valid_0's ndcg@4: 0.847422 valid_0's ndcg@8: 0.859022 valid_0's ndcg@15: 0.877082
# valid_0's ndcg@4: 0.851195 valid_0's ndcg@8: 0.861618 valid_0's ndcg@15: 0.879057
# valid_0's ndcg@4: 0.851195 valid_0's ndcg@8: 0.863214 valid_0's ndcg@15: 0.879142
# ========================================================================================
# [LightGBM] [Info] Total Bins 2071
# [LightGBM] [Info] Number of data points in the train set: 3907, number of used features: 10
# valid_0's ndcg@4: 0.414114 valid_0's ndcg@8: 0.477011 valid_0's ndcg@15: 0.627188
# valid_0's ndcg@4: 0.635937 valid_0's ndcg@8: 0.718764 valid_0's ndcg@15: 0.764518
# valid_0's ndcg@4: 0.738547 valid_0's ndcg@8: 0.780225 valid_0's ndcg@15: 0.798098
# valid_0's ndcg@4: 0.738180 valid_0's ndcg@8: 0.779479 valid_0's ndcg@15: 0.800814
# valid_0's ndcg@4: 0.750149 valid_0's ndcg@8: 0.785259 valid_0's ndcg@15: 0.804071
# valid_0's ndcg@4: 0.744679 valid_0's ndcg@8: 0.779228 valid_0's ndcg@15: 0.800078
# valid_0's ndcg@4: 0.749038 valid_0's ndcg@8: 0.781492 valid_0's ndcg@15: 0.800406
# valid_0's ndcg@4: 0.742652 valid_0's ndcg@8: 0.781109 valid_0's ndcg@15: 0.800123
# valid_0's ndcg@4: 0.758044 valid_0's ndcg@8: 0.787709 valid_0's ndcg@15: 0.805897
# valid_0's ndcg@4: 0.759722 valid_0's ndcg@8: 0.786207 valid_0's ndcg@15: 0.804931
# ========================================================================================
# [LightGBM] [Info] Total Bins 2678
# [LightGBM] [Info] Number of data points in the train set: 4246, number of used features: 13
# valid_0's ndcg@4: 0.532637 valid_0's ndcg@8: 0.595625 valid_0's ndcg@15: 0.711448
# valid_0's ndcg@4: 0.736134 valid_0's ndcg@8: 0.767824 valid_0's ndcg@15: 0.787990
# valid_0's ndcg@4: 0.823668 valid_0's ndcg@8: 0.805621 valid_0's ndcg@15: 0.821147
# valid_0's ndcg@4: 0.826040 valid_0's ndcg@8: 0.818018 valid_0's ndcg@15: 0.825306
# valid_0's ndcg@4: 0.816975 valid_0's ndcg@8: 0.815394 valid_0's ndcg@15: 0.832542
# valid_0's ndcg@4: 0.820774 valid_0's ndcg@8: 0.818778 valid_0's ndcg@15: 0.833862
# valid_0's ndcg@4: 0.809704 valid_0's ndcg@8: 0.812983 valid_0's ndcg@15: 0.829861
# valid_0's ndcg@4: 0.811282 valid_0's ndcg@8: 0.809192 valid_0's ndcg@15: 0.830121
# valid_0's ndcg@4: 0.811282 valid_0's ndcg@8: 0.807602 valid_0's ndcg@15: 0.831327
# valid_0's ndcg@4: 0.808490 valid_0's ndcg@8: 0.806387 valid_0's ndcg@15: 0.829437
# ========================================================================================
# [LightGBM] [Info] Total Bins 2670
# [LightGBM] [Info] Number of data points in the train set: 4246, number of used features: 13
# valid_0's ndcg@4: 0.570328 valid_0's ndcg@8: 0.637473 valid_0's ndcg@15: 0.723702
# valid_0's ndcg@4: 0.697387 valid_0's ndcg@8: 0.720609 valid_0's ndcg@15: 0.764196
# valid_0's ndcg@4: 0.745468 valid_0's ndcg@8: 0.739601 valid_0's ndcg@15: 0.771310
# valid_0's ndcg@4: 0.750500 valid_0's ndcg@8: 0.743884 valid_0's ndcg@15: 0.774722
# valid_0's ndcg@4: 0.759228 valid_0's ndcg@8: 0.753404 valid_0's ndcg@15: 0.782309
# valid_0's ndcg@4: 0.760157 valid_0's ndcg@8: 0.747182 valid_0's ndcg@15: 0.778005
# valid_0's ndcg@4: 0.768290 valid_0's ndcg@8: 0.763584 valid_0's ndcg@15: 0.788639
# valid_0's ndcg@4: 0.773031 valid_0's ndcg@8: 0.763752 valid_0's ndcg@15: 0.786526
# valid_0's ndcg@4: 0.763572 valid_0's ndcg@8: 0.756700 valid_0's ndcg@15: 0.783789
# valid_0's ndcg@4: 0.764895 valid_0's ndcg@8: 0.755697 valid_0's ndcg@15: 0.788950
# ========================================================================================
# [LightGBM] [Info] Total Bins 2667
# [LightGBM] [Info] Number of data points in the train set: 4286, number of used features: 13
# valid_0's ndcg@4: 0.659234 valid_0's ndcg@8: 0.713202 valid_0's ndcg@15: 0.789727
# valid_0's ndcg@4: 0.805688 valid_0's ndcg@8: 0.840251 valid_0's ndcg@15: 0.868920
# valid_0's ndcg@4: 0.854567 valid_0's ndcg@8: 0.867577 valid_0's ndcg@15: 0.897047
# valid_0's ndcg@4: 0.895037 valid_0's ndcg@8: 0.883068 valid_0's ndcg@15: 0.907305
# valid_0's ndcg@4: 0.885481 valid_0's ndcg@8: 0.868852 valid_0's ndcg@15: 0.897170
# valid_0's ndcg@4: 0.872230 valid_0's ndcg@8: 0.881888 valid_0's ndcg@15: 0.906322
# valid_0's ndcg@4: 0.884458 valid_0's ndcg@8: 0.889344 valid_0's ndcg@15: 0.903892
# valid_0's ndcg@4: 0.873026 valid_0's ndcg@8: 0.878312 valid_0's ndcg@15: 0.896247
# valid_0's ndcg@4: 0.885305 valid_0's ndcg@8: 0.886957 valid_0's ndcg@15: 0.904515
# valid_0's ndcg@4: 0.887679 valid_0's ndcg@8: 0.882002 valid_0's ndcg@15: 0.905039
# ========================================================================================
# [LightGBM] [Info] Total Bins 2677
# [LightGBM] [Info] Number of data points in the train set: 4286, number of used features: 13
# valid_0's ndcg@4: 0.540093 valid_0's ndcg@8: 0.626439 valid_0's ndcg@15: 0.740570
# valid_0's ndcg@4: 0.759313 valid_0's ndcg@8: 0.822005 valid_0's ndcg@15: 0.849733
# valid_0's ndcg@4: 0.858992 valid_0's ndcg@8: 0.841427 valid_0's ndcg@15: 0.885915
# valid_0's ndcg@4: 0.859037 valid_0's ndcg@8: 0.847517 valid_0's ndcg@15: 0.884498
# valid_0's ndcg@4: 0.809906 valid_0's ndcg@8: 0.844501 valid_0's ndcg@15: 0.875060
# valid_0's ndcg@4: 0.820064 valid_0's ndcg@8: 0.849373 valid_0's ndcg@15: 0.877114
# valid_0's ndcg@4: 0.820064 valid_0's ndcg@8: 0.850179 valid_0's ndcg@15: 0.876926
# valid_0's ndcg@4: 0.821978 valid_0's ndcg@8: 0.851904 valid_0's ndcg@15: 0.873950
# valid_0's ndcg@4: 0.841756 valid_0's ndcg@8: 0.858877 valid_0's ndcg@15: 0.883768
# valid_0's ndcg@4: 0.806143 valid_0's ndcg@8: 0.837391 valid_0's ndcg@15: 0.868574
# ========================================================================================
# [LightGBM] [Info] Total Bins 2683
# [LightGBM] [Info] Number of data points in the train set: 4286, number of used features: 13
# valid_0's ndcg@4: 0.667619 valid_0's ndcg@8: 0.684760 valid_0's ndcg@15: 0.772244
# valid_0's ndcg@4: 0.698796 valid_0's ndcg@8: 0.761721 valid_0's ndcg@15: 0.811225
# valid_0's ndcg@4: 0.768086 valid_0's ndcg@8: 0.786280 valid_0's ndcg@15: 0.825432
# valid_0's ndcg@4: 0.791113 valid_0's ndcg@8: 0.804650 valid_0's ndcg@15: 0.833516
# valid_0's ndcg@4: 0.800850 valid_0's ndcg@8: 0.815417 valid_0's ndcg@15: 0.835949
# valid_0's ndcg@4: 0.800855 valid_0's ndcg@8: 0.814274 valid_0's ndcg@15: 0.834785
# valid_0's ndcg@4: 0.824048 valid_0's ndcg@8: 0.819558 valid_0's ndcg@15: 0.842618
# valid_0's ndcg@4: 0.821822 valid_0's ndcg@8: 0.817501 valid_0's ndcg@15: 0.842553
# valid_0's ndcg@4: 0.812657 valid_0's ndcg@8: 0.822880 valid_0's ndcg@15: 0.842642
# valid_0's ndcg@4: 0.813423 valid_0's ndcg@8: 0.825161 valid_0's ndcg@15: 0.842578
# ========================================================================================
# [LightGBM] [Info] Total Bins 2670
# [LightGBM] [Info] Number of data points in the train set: 4286, number of used features: 13
# valid_0's ndcg@4: 0.495822 valid_0's ndcg@8: 0.629291 valid_0's ndcg@15: 0.694140
# valid_0's ndcg@4: 0.825945 valid_0's ndcg@8: 0.810355 valid_0's ndcg@15: 0.799968
# valid_0's ndcg@4: 0.828487 valid_0's ndcg@8: 0.805511 valid_0's ndcg@15: 0.806393
# valid_0's ndcg@4: 0.815660 valid_0's ndcg@8: 0.803677 valid_0's ndcg@15: 0.815219
# valid_0's ndcg@4: 0.799044 valid_0's ndcg@8: 0.799358 valid_0's ndcg@15: 0.810100
# valid_0's ndcg@4: 0.806102 valid_0's ndcg@8: 0.797835 valid_0's ndcg@15: 0.806732
# valid_0's ndcg@4: 0.825079 valid_0's ndcg@8: 0.806701 valid_0's ndcg@15: 0.814024
# valid_0's ndcg@4: 0.812245 valid_0's ndcg@8: 0.805252 valid_0's ndcg@15: 0.812290
# valid_0's ndcg@4: 0.807771 valid_0's ndcg@8: 0.804323 valid_0's ndcg@15: 0.812270
# valid_0's ndcg@4: 0.812332 valid_0's ndcg@8: 0.805542 valid_0's ndcg@15: 0.813350
# ========================================================================================
# [LightGBM] [Info] Total Bins 2668
# [LightGBM] [Info] Number of data points in the train set: 4286, number of used features: 13
# valid_0's ndcg@4: 0.659312 valid_0's ndcg@8: 0.726030 valid_0's ndcg@15: 0.794429
# valid_0's ndcg@4: 0.838178 valid_0's ndcg@8: 0.831294 valid_0's ndcg@15: 0.850232
# valid_0's ndcg@4: 0.834869 valid_0's ndcg@8: 0.841277 valid_0's ndcg@15: 0.857419
# valid_0's ndcg@4: 0.835266 valid_0's ndcg@8: 0.842106 valid_0's ndcg@15: 0.856321
# valid_0's ndcg@4: 0.842683 valid_0's ndcg@8: 0.835267 valid_0's ndcg@15: 0.858413
# valid_0's ndcg@4: 0.843491 valid_0's ndcg@8: 0.843528 valid_0's ndcg@15: 0.862769
# valid_0's ndcg@4: 0.838550 valid_0's ndcg@8: 0.842065 valid_0's ndcg@15: 0.862844
# valid_0's ndcg@4: 0.837022 valid_0's ndcg@8: 0.842481 valid_0's ndcg@15: 0.861572
# valid_0's ndcg@4: 0.844930 valid_0's ndcg@8: 0.846713 valid_0's ndcg@15: 0.863679
# valid_0's ndcg@4: 0.845422 valid_0's ndcg@8: 0.850731 valid_0's ndcg@15: 0.864597
# ========================================================================================
# [LightGBM] [Info] Total Bins 2677
# [LightGBM] [Info] Number of data points in the train set: 4246, number of used features: 13
# valid_0's ndcg@4: 0.614756 valid_0's ndcg@8: 0.676236 valid_0's ndcg@15: 0.741342
# valid_0's ndcg@4: 0.733860 valid_0's ndcg@8: 0.743952 valid_0's ndcg@15: 0.801942
# valid_0's ndcg@4: 0.757025 valid_0's ndcg@8: 0.794945 valid_0's ndcg@15: 0.817230
# valid_0's ndcg@4: 0.791093 valid_0's ndcg@8: 0.803781 valid_0's ndcg@15: 0.828142
# valid_0's ndcg@4: 0.779232 valid_0's ndcg@8: 0.798145 valid_0's ndcg@15: 0.823961
# valid_0's ndcg@4: 0.791597 valid_0's ndcg@8: 0.812271 valid_0's ndcg@15: 0.829557
# valid_0's ndcg@4: 0.788304 valid_0's ndcg@8: 0.802641 valid_0's ndcg@15: 0.827867
# valid_0's ndcg@4: 0.793674 valid_0's ndcg@8: 0.803454 valid_0's ndcg@15: 0.829521
# valid_0's ndcg@4: 0.792047 valid_0's ndcg@8: 0.801314 valid_0's ndcg@15: 0.823944
# valid_0's ndcg@4: 0.794336 valid_0's ndcg@8: 0.800566 valid_0's ndcg@15: 0.826384
# ========================================================================================
# [LightGBM] [Info] Total Bins 2666
# [LightGBM] [Info] Number of data points in the train set: 4246, number of used features: 13
# valid_0's ndcg@4: 0.459176 valid_0's ndcg@8: 0.554314 valid_0's ndcg@15: 0.696106
# valid_0's ndcg@4: 0.713942 valid_0's ndcg@8: 0.774809 valid_0's ndcg@15: 0.794808
# valid_0's ndcg@4: 0.765229 valid_0's ndcg@8: 0.804025 valid_0's ndcg@15: 0.805455
# valid_0's ndcg@4: 0.803101 valid_0's ndcg@8: 0.808079 valid_0's ndcg@15: 0.824457
# valid_0's ndcg@4: 0.803327 valid_0's ndcg@8: 0.808765 valid_0's ndcg@15: 0.820942
# valid_0's ndcg@4: 0.806573 valid_0's ndcg@8: 0.816044 valid_0's ndcg@15: 0.820765
# valid_0's ndcg@4: 0.813950 valid_0's ndcg@8: 0.811727 valid_0's ndcg@15: 0.822376
# valid_0's ndcg@4: 0.811148 valid_0's ndcg@8: 0.802502 valid_0's ndcg@15: 0.824642
# valid_0's ndcg@4: 0.805729 valid_0's ndcg@8: 0.802134 valid_0's ndcg@15: 0.821474
# valid_0's ndcg@4: 0.805729 valid_0's ndcg@8: 0.803407 valid_0's ndcg@15: 0.820404
# ========================================================================================
# [LightGBM] [Info] Total Bins 2673
# [LightGBM] [Info] Number of data points in the train set: 4246, number of used features: 13
# valid_0's ndcg@4: 0.703059 valid_0's ndcg@8: 0.711039 valid_0's ndcg@15: 0.761289
# valid_0's ndcg@4: 0.763285 valid_0's ndcg@8: 0.779131 valid_0's ndcg@15: 0.785204
# valid_0's ndcg@4: 0.815136 valid_0's ndcg@8: 0.800430 valid_0's ndcg@15: 0.800152
# valid_0's ndcg@4: 0.822067 valid_0's ndcg@8: 0.812563 valid_0's ndcg@15: 0.804396
# valid_0's ndcg@4: 0.825335 valid_0's ndcg@8: 0.812796 valid_0's ndcg@15: 0.809207
# valid_0's ndcg@4: 0.828286 valid_0's ndcg@8: 0.820139 valid_0's ndcg@15: 0.816717
# valid_0's ndcg@4: 0.828902 valid_0's ndcg@8: 0.816826 valid_0's ndcg@15: 0.806122
# valid_0's ndcg@4: 0.824699 valid_0's ndcg@8: 0.812351 valid_0's ndcg@15: 0.809740
# valid_0's ndcg@4: 0.825776 valid_0's ndcg@8: 0.811606 valid_0's ndcg@15: 0.807239
# valid_0's ndcg@4: 0.824382 valid_0's ndcg@8: 0.817319 valid_0's ndcg@15: 0.809676
# ========================================================================================
# Final individual evaluation results saved.
# Average NDCG@4 Score: 0.7976
# Average NDCG@8 Score: 0.8112
# Average NDCG@15 Score: 0.8286
# Game averages evaluation results saved.
